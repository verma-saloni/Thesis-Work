# %% [markdown]
# <a href="https://colab.research.google.com/github/verma-saloni/Thesis-Work/blob/main/4_5_22_3_SBERT_Embeddings_extra_XGboost_Politifact_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install -U xgboost sentence-transformers wandb

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import re
import json

from sentence_transformers import SentenceTransformer 

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
import xgboost as xgb

import wandb
from wandb.xgboost import WandbCallback
from IPython.display import clear_output

# %%
metrics = [accuracy_score, f1_score, precision_score, recall_score]

def get_name(score_func):
    return score_func.__name__.split("_")[0]

# %% [markdown]
# # Load data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
base_dir = Path("/content/drive/MyDrive/Research FakeNews")
assert base_dir.exists()

# %%
import ast

converters = {"retweets":ast.literal_eval, "tweets":ast.literal_eval}
df = pd.read_csv(base_dir/"politifact.csv", index_col=0, converters=converters, parse_dates=["publish_date"])
df.head()
# Out:
#                id label                                                url  \
# 0  politifact1212  real  http://www.youtube.com/watch?v=5zrsl8o4ZPo&fea...
# 1  politifact6730  real  http://www.motherjones.com/politics/2012/09/se...
# 2  politifact2298  real  https://web.archive.org/web/20050322064340/htt...
# 3    politifact87  real  http://www.ilga.gov/legislation/BillStatus.asp...
# 4  politifact3180  real  http://abcnews.go.com/Politics/rand-paul-repub...
#
#                                                 text  \
# 0  ein Google-Unternehmen\n\nDienste anbieten und...
# 1  During a private fundraiser earlier this year,...
# 2  COPYRIGHT © 2005 LexisNexis, a division of Ree...
# 3  ×\n\nThe Illinois General Assembly offers the ...
# 4  Feb. 4, 2011  -- In an exclusive interview wi...
#
#                                              top_img keywords  \
# 0                  http://www.google.com/favicon.ico       []
# 1  https://www.motherjones.com/wp-content/uploads...       []
# 2                                                NaN       []
# 3                   http://www.ilga.gov/LISlogo1.ico       []
# 4  http://abcnews.go.com/Politics/rand-paul-repub...       []
#
#                                              authors  \
# 0                                                 []
# 1  ['David Corn', 'Dave Gilson', 'Tim Murphy', 'B...
# 2                                                 []
# 3                                                 []
# 4          ['Abc News', 'Jonathan Karl', 'February']
#
#                                       canonical_link  \
# 0                                                NaN
# 1  https://www.motherjones.com/politics/2012/09/s...
# 2                                                NaN
# 3                                                NaN
# 4  https://abcnews.go.com/Politics/rand-paul-repu...
#
#                                                title  \
# 0                   Bevor Sie zu YouTube weitergehen
# 1  SECRET VIDEO: Romney Tells Millionaire Donors ...
# 2                            LexisNexis(R) Publisher
# 3                          Illinois General Assembly
# 4  ABC News Exclusive: Rand Paul Says Republicans...
#
#                                            meta_data  publish_date  \
# 0  {'viewport': 'initial-scale=1, maximum-scale=5...           NaN
# 1  {'viewport': 'width=device-width, initial-scal...  1347904858.0
# 2                                                 {}           NaN
# 3  {'classification': 'Government', 'distribution...           NaN
# 4  {'description': 'In an exclusive interview wit...           NaN
#
#                        source  summary retweets  \
# 0      http://www.youtube.com      NaN       []
# 1  http://www.motherjones.com      NaN       []
# 2     https://web.archive.org      NaN       []
# 3         http://www.ilga.gov      NaN       []
# 4       http://abcnews.go.com      NaN       []
#
#                                               tweets
# 0  [{'id': None, 'text': None, 'retweet_count': N...
# 1  [{'id': None, 'text': None, 'retweet_count': N...
# 2  [{'id': None, 'text': None, 'retweet_count': N...
# 3                                                 []
# 4                                                 []

# %%
df.title.isna().sum(), (df.title == "").sum()
# Out:
# (0, 0)

# %%
dup_titles, dup_groups = [], []
for name, group in df.groupby("title"):
    if len(group) > 1:
        dup_titles.append(name)
        dup_groups.append(group)

# %%
bckp = df.copy()

# %%
agg_funcs = {"text":"max", "tweets":"sum", "retweets":"sum", "label":"first", "url":"first"}
df.text.fillna("", inplace=True)
df = df.groupby("title", as_index=False).agg(agg_funcs)
df.head()
# Out:
#                                                title  \
# 0   Actress Emma Stone ‘For the first time in his...
# 1   Breaking President Trump makes English the of...
# 2   Friendly Fire … Charlottesville Car attacker ...
# 3   If You Are Using This Toothpaste… Throw It Aw...
# 4  "Face the Nation" transcripts, August 26, 2012...
#
#                                                 text  \
# 0
# 1
# 2
# 3  MightyLiving Blog\n\nHelpful inspiration from ...
# 4  "Face the Nation" transcripts, August 26, 2012...
#
#                                               tweets  \
# 0  [{'id': None, 'text': None, 'retweet_count': N...
# 1  [{'id': None, 'text': None, 'retweet_count': N...
# 2  [{'id': None, 'text': None, 'retweet_count': N...
# 3  [{'id': None, 'text': None, 'retweet_count': N...
# 4  [{'id': None, 'text': None, 'retweet_count': N...
#
#                                             retweets label  \
# 0                                                 []  fake
# 1                                                 []  fake
# 2                                                 []  fake
# 3  [888249387134066689, 882233433228967937, 88290...  fake
# 4                                                 []  real
#
#                                                  url
# 0                                               None
# 1                                               None
# 2                                               None
# 3  mightynest.com/learn/research-by-concern/dange...
# 4  https://web.archive.org/web/20120827001956/htt...

# %%
titles = df.title.tolist()
texts = (df.title + " " + df.text).tolist()

# %%
len(texts)
# Out:
# 894

# %% [markdown]
# # Compute emebeddings

# %%
embedding_file = base_dir/"sbert_title_embeddings.npy"

if embedding_file.exists():
    title_embeddings = np.load(embedding_file)
else:
    model_id = "all-mpnet-base-v2"
    model = SentenceTransformer(model_id)

    title_embeddings = model.encode(titles, show_progress_bar=True)
    np.save(embedding_file, title_embeddings)

# %%
embedding_file = base_dir/"sbert_fulltext_embeddings.npy"

if embedding_file.exists():
    text_embeddings = np.load(embedding_file)
else:
    model_id = "all-mpnet-base-v2"
    model = SentenceTransformer(model_id)

    text_embeddings = model.encode(texts, show_progress_bar=True)
    np.save(embedding_file, text_embeddings)

# %% [markdown]
# # Extra features
#
# TODO: feel free to suggest more features here

# %% [markdown]
# ## Source

# %%
source = df.url.str.replace("^(https://)?web.archive.org/web/\d+/", "", regex=True)

# %%
source = source.str.replace("^(https?://)?(www.)?", "", regex=True)

# %%
source = source.str.replace("\.(com|info|org|gov|tv|us|news|me|co.uk|net|club|co|live|edu|xyz|site|life|ru|online|tk|website|pw|one|world|mil).*$", "", regex=True)

# %%
len(source), len(source.unique())
# Out:
# (894, 519)

# %% [markdown]
# ## Number of retweets

# %%
# df["tweet_id"] = df.twee

# %%
df["num_retweets"] = df.retweets.map(lambda x: len(set(x)))
df["log_num_retweets"] = np.log1p(df.num_retweets.to_numpy())
df["num_tweets"] = df.tweets.map(len)
df["log_num_tweets"] = np.log1p(df.num_tweets.to_numpy())

# %%
df.describe()
# Out:
#        num_retweets  log_num_retweets    num_tweets  log_num_tweets
# count    894.000000        894.000000    894.000000      894.000000
# mean      70.429530          0.816070    646.885906        3.430624
# std      777.210478          1.855284   2746.769221        2.692058
# min        0.000000          0.000000      0.000000        0.000000
# 25%        0.000000          0.000000      1.000000        0.693147
# 50%        0.000000          0.000000     33.000000        3.526361
# 75%        0.000000          0.000000    240.750000        5.487903
# max    21984.000000          9.998116  39919.000000       10.594633

# %% [markdown]
# ## More to come

# %% [markdown]
# # Training

# %% [markdown]
# ### Title embeddings

# %%
X = title_embeddings
y = (df.label=="real").to_numpy().astype(int)

X.shape, y.shape
# Out:
# ((894, 768), (894,))

# %%
skf = StratifiedKFold(shuffle=True, random_state=124)

# %%
def train(train_idx, test_idx, params):

    # training
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dtest = xgb.DMatrix(X_test, label=y_test)
    watchlist = [(dtrain,'train'), (dtest,'eval')]
    clf = xgb.train(params, dtrain, num_boost_round=100, early_stopping_rounds=None, evals=watchlist, callbacks=[WandbCallback()])
    #evaluation
    probs = clf.predict(dtest)
    y_pred = (probs > 0.5).astype(int)
    eval_results = {get_name(f):f(y_pred=y_pred, y_true=y_test) for f in metrics}
    wandb.log(eval_results)
    wandb.log({"conf_mat" : wandb.plot.confusion_matrix(probs=None,
                            y_true=y_test, preds=y_pred,
                            class_names=["Fake", "Real"])})

# %%
params = {
    "objective":'binary:logistic',
    "seed":124
}

# %%
GROUP = "sbert-mpnet-v2-title-xgb"

for fold_id, (train_idx, test_idx) in enumerate(skf.split(X, y)):
    clear_output()
    with wandb.init(entity="saloniteam", project="fnd", group=GROUP, name=f"{GROUP}-fold-{fold_id}") as run:
        train(train_idx, test_idx, params)
# Out:
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/wandb/run-20220504_202829-fx5mgl8p</code>
# Syncing run <strong><a href="https://wandb.ai/saloniteam/fnd/runs/fx5mgl8p" target="_blank">sbert-mpnet-v2-title-xgb-fold-4</a></strong> to <a href="https://wandb.ai/saloniteam/fnd" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# [0]	train-logloss:0.48666	eval-logloss:0.62056
# [1]	train-logloss:0.36886	eval-logloss:0.57794
# [2]	train-logloss:0.28538	eval-logloss:0.53091
# [3]	train-logloss:0.22380	eval-logloss:0.51001
# [4]	train-logloss:0.18164	eval-logloss:0.49504
# [5]	train-logloss:0.14780	eval-logloss:0.47909
# [6]	train-logloss:0.12258	eval-logloss:0.46907
# [7]	train-logloss:0.10261	eval-logloss:0.46918
# [8]	train-logloss:0.08639	eval-logloss:0.45978
# [9]	train-logloss:0.07478	eval-logloss:0.46155
# [10]	train-logloss:0.06401	eval-logloss:0.46466
# [11]	train-logloss:0.05624	eval-logloss:0.45765
# [12]	train-logloss:0.04974	eval-logloss:0.45079
# [13]	train-logloss:0.04451	eval-logloss:0.44738
# [14]	train-logloss:0.04038	eval-logloss:0.44196
# [15]	train-logloss:0.03674	eval-logloss:0.43572
# [72]	train-logloss:0.00580	eval-logloss:0.44727
# [73]	train-logloss:0.00574	eval-logloss:0.44572
# [74]	train-logloss:0.00569	eval-logloss:0.44573
# [75]	train-logloss:0.00563	eval-logloss:0.44640
# [76]	train-logloss:0.00557	eval-logloss:0.44796
# [77]	train-logloss:0.00552	eval-logloss:0.44854
# [78]	train-logloss:0.00547	eval-logloss:0.44956
# [79]	train-logloss:0.00541	eval-logloss:0.44804
# [80]	train-logloss:0.00536	eval-logloss:0.44746
# [81]	train-logloss:0.00531	eval-logloss:0.44535
# [82]	train-logloss:0.00526	eval-logloss:0.44836
# [83]	train-logloss:0.00521	eval-logloss:0.44911
# [84]	train-logloss:0.00517	eval-logloss:0.44859
# [85]	train-logloss:0.00515	eval-logloss:0.44832
# [86]	train-logloss:0.00510	eval-logloss:0.45045
# [87]	train-logloss:0.00505	eval-logloss:0.45007
# [88]	train-logloss:0.00501	eval-logloss:0.45134
# [89]	train-logloss:0.00499	eval-logloss:0.45008
# [90]	train-logloss:0.00495	eval-logloss:0.45030
# [91]	train-logloss:0.00491	eval-logloss:0.45185
# [92]	train-logloss:0.00486	eval-logloss:0.45426
# [93]	train-logloss:0.00482	eval-logloss:0.45341
# [94]	train-logloss:0.00480	eval-logloss:0.45311
# [95]	train-logloss:0.00476	eval-logloss:0.45239
# [96]	train-logloss:0.00472	eval-logloss:0.45146
# [97]	train-logloss:0.00468	eval-logloss:0.45218
# [98]	train-logloss:0.00466	eval-logloss:0.45142
# [99]	train-logloss:0.00464	eval-logloss:0.45013
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.021 MB of 0.021 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>eval-logloss</td><td>█▅▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▁▁▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂</td></tr><tr><td>f1</td><td>▁</td></tr><tr><td>precision</td><td>▁</td></tr><tr><td>recall</td><td>▁</td></tr><tr><td>train-logloss</td><td>█▅▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.81461</td></tr><tr><td>epoch</td><td>99</td></tr><tr><td>f1</td><td>0.82902</td></tr><tr><td>precision</td><td>0.82474</td></tr><tr><td>recall</td><td>0.83333</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">sbert-mpnet-v2-title-xgb-fold-4</strong>: <a href="https://wandb.ai/saloniteam/fnd/runs/fx5mgl8p" target="_blank">https://wandb.ai/saloniteam/fnd/runs/fx5mgl8p</a><br/>Synced 5 W&B file(s), 2 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220504_202829-fx5mgl8p/logs</code>

# %% [markdown]
# ### Text embeddings

# %%
X = text_embeddings
y = (df.label=="real").to_numpy().astype(int)

X.shape, y.shape
# Out:
# ((894, 768), (894,))

# %%
skf = StratifiedKFold(shuffle=True, random_state=124)

# %%
def train(train_idx, test_idx, params):

    # training
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dtest = xgb.DMatrix(X_test, label=y_test)
    watchlist = [(dtrain,'train'), (dtest,'eval')]
    clf = xgb.train(params, dtrain, num_boost_round=100, early_stopping_rounds=None, evals=watchlist, callbacks=[WandbCallback()])
    #evaluation
    probs = clf.predict(dtest)
    y_pred = (probs > 0.5).astype(int)
    eval_results = {get_name(f):f(y_pred=y_pred, y_true=y_test) for f in metrics}
    wandb.log(eval_results)
    wandb.log({"conf_mat" : wandb.plot.confusion_matrix(probs=None,
                            y_true=y_test, preds=y_pred,
                            class_names=["Fake", "Real"])})

# %%
params = {
    "objective":'binary:logistic',
    "seed":124
}

# %%
GROUP = "sbert-mpnet-v2-fulltext-xgb"
for fold_id, (train_idx, test_idx) in enumerate(skf.split(X, y)):
    clear_output()
    with wandb.init(entity="saloniteam", project="fnd", group=GROUP, name=f"{GROUP}-fold-{fold_id}") as run:
        train(train_idx, test_idx, params)
# Out:
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/wandb/run-20220504_202946-m1w4zr82</code>
# Syncing run <strong><a href="https://wandb.ai/saloniteam/fnd/runs/m1w4zr82" target="_blank">sbert-mpnet-v2-fulltext-xgb-fold-4</a></strong> to <a href="https://wandb.ai/saloniteam/fnd" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# [0]	train-logloss:0.49802	eval-logloss:0.60112
# [1]	train-logloss:0.37041	eval-logloss:0.55713
# [2]	train-logloss:0.28558	eval-logloss:0.51866
# [3]	train-logloss:0.22281	eval-logloss:0.48339
# [4]	train-logloss:0.17741	eval-logloss:0.47409
# [5]	train-logloss:0.14721	eval-logloss:0.45542
# [6]	train-logloss:0.11919	eval-logloss:0.44750
# [7]	train-logloss:0.09922	eval-logloss:0.42893
# [8]	train-logloss:0.08325	eval-logloss:0.43532
# [9]	train-logloss:0.07114	eval-logloss:0.43011
# [10]	train-logloss:0.06135	eval-logloss:0.42342
# [11]	train-logloss:0.05304	eval-logloss:0.41455
# [12]	train-logloss:0.04676	eval-logloss:0.41704
# [13]	train-logloss:0.04149	eval-logloss:0.41046
# [14]	train-logloss:0.03699	eval-logloss:0.40922
# [15]	train-logloss:0.03338	eval-logloss:0.40820
# [16]	train-logloss:0.03049	eval-logloss:0.40937
# [17]	train-logloss:0.02792	eval-logloss:0.41175
# [18]	train-logloss:0.02571	eval-logloss:0.41297
# [19]	train-logloss:0.02396	eval-logloss:0.41544
# [20]	train-logloss:0.02230	eval-logloss:0.41041
# [21]	train-logloss:0.02080	eval-logloss:0.40802
# [22]	train-logloss:0.01944	eval-logloss:0.41030
# [23]	train-logloss:0.01834	eval-logloss:0.41302
# [24]	train-logloss:0.01726	eval-logloss:0.41382
# [25]	train-logloss:0.01633	eval-logloss:0.42058
# [26]	train-logloss:0.01550	eval-logloss:0.41891
# [27]	train-logloss:0.01483	eval-logloss:0.42027
# [28]	train-logloss:0.01414	eval-logloss:0.41807
# [29]	train-logloss:0.01355	eval-logloss:0.42126
# [30]	train-logloss:0.01301	eval-logloss:0.42284
# [31]	train-logloss:0.01252	eval-logloss:0.42438
# [32]	train-logloss:0.01203	eval-logloss:0.42735
# [33]	train-logloss:0.01156	eval-logloss:0.42689
# [34]	train-logloss:0.01109	eval-logloss:0.42846
# [35]	train-logloss:0.01074	eval-logloss:0.42707
# [36]	train-logloss:0.01037	eval-logloss:0.42966
# [37]	train-logloss:0.01004	eval-logloss:0.42834
# [38]	train-logloss:0.00970	eval-logloss:0.42529
# [39]	train-logloss:0.00945	eval-logloss:0.42780
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.017 MB of 0.017 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>eval-logloss</td><td>█▅▃▂▂▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▂▂▃▃▂▂▂▂▂▂▃▃▃▃▃▃▃▃▃▃</td></tr><tr><td>f1</td><td>▁</td></tr><tr><td>precision</td><td>▁</td></tr><tr><td>recall</td><td>▁</td></tr><tr><td>train-logloss</td><td>█▅▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.83708</td></tr><tr><td>epoch</td><td>99</td></tr><tr><td>f1</td><td>0.84656</td></tr><tr><td>precision</td><td>0.86022</td></tr><tr><td>recall</td><td>0.83333</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">sbert-mpnet-v2-fulltext-xgb-fold-4</strong>: <a href="https://wandb.ai/saloniteam/fnd/runs/m1w4zr82" target="_blank">https://wandb.ai/saloniteam/fnd/runs/m1w4zr82</a><br/>Synced 5 W&B file(s), 2 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220504_202946-m1w4zr82/logs</code>

# %% [markdown]
# ### + num tweets and retweets

# %%
X = np.concatenate([text_embeddings, df.num_retweets.to_numpy()[..., None], df.num_tweets.to_numpy()[..., None]], axis=1)
y = (df.label=="real").to_numpy().astype(int)

X.shape, y.shape
# Out:
# ((894, 770), (894,))

# %%
skf = StratifiedKFold(shuffle=True, random_state=124)

# %%
def train(train_idx, test_idx, params):

    # training
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dtest = xgb.DMatrix(X_test, label=y_test)
    watchlist = [(dtrain,'train'), (dtest,'eval')]
    clf = xgb.train(params, dtrain, num_boost_round=100, early_stopping_rounds=None, evals=watchlist, callbacks=[WandbCallback()])
    #evaluation
    probs = clf.predict(dtest)
    y_pred = (probs > 0.5).astype(int)
    eval_results = {get_name(f):f(y_pred=y_pred, y_true=y_test) for f in metrics}
    wandb.log(eval_results)
    wandb.log({"conf_mat" : wandb.plot.confusion_matrix(probs=None,
                            y_true=y_test, preds=y_pred,
                            class_names=["Fake", "Real"])})

# %%
params = {
    "objective":'binary:logistic',
    "seed":124
}

# %%
GROUP = "sbert-mpnet-v2-fulltext-tw-xgb"
for fold_id, (train_idx, test_idx) in enumerate(skf.split(X, y)):
    clear_output()
    with wandb.init(entity="saloniteam", project="fnd", group=GROUP, name=f"{GROUP}-fold-{fold_id}") as run:
        train(train_idx, test_idx, params)
# Out:
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/wandb/run-20220504_203113-fqdqxxn3</code>
# Syncing run <strong><a href="https://wandb.ai/saloniteam/fnd/runs/fqdqxxn3" target="_blank">sbert-mpnet-v2-fulltext-tw-xgb-fold-4</a></strong> to <a href="https://wandb.ai/saloniteam/fnd" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
