# %% [markdown]
# <a href="https://colab.research.google.com/github/verma-saloni/Thesis-Work/blob/main/07_10-22_SBERT_nn_200_pol.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U xgboost sentence-transformers wandb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xgboost in /usr/local/lib/python3.7/dist-packages (0.90)
# Collecting xgboost
#   Downloading xgboost-1.6.1-py3-none-manylinux2014_x86_64.whl (192.9 MB)
#      |████████████████████████████████| 192.9 MB 64 kB/s
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      |████████████████████████████████| 85 kB 3.3 MB/s
# Collecting wandb
#   Downloading wandb-0.12.21-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 40.9 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.4.1)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.20.1-py3-none-any.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 38.8 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (4.64.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.11.0+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.12.0+cu113)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.0.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (3.7)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 42.8 MB/s
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 8.6 MB/s
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (21.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.23.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 12.1 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.11.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers) (3.0.9)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 52.7 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.6.2)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.6.0-py2.py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 71.4 MB/s
# Requirement already satisfied: protobuf<4.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 38.6 MB/s
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Collecting setproctitle
#   Downloading setproctitle-1.2.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from wandb) (57.4.0)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.0 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.24.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->huggingface-hub>=0.4.0->sentence-transformers) (3.8.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers) (7.1.2)
# Building wheels for collected packages: sentence-transformers, pathtools
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=0589a6ab4778211e41719b28f63643601c46650e3a65b90f62c5960ae7fc20b9
#   Stored in directory: /root/.cache/pip/wheels/bf/06/fb/d59c1e5bd1dac7f6cf61ec0036cc3a10ab8fecaa6b2c3d3ee9
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=6954abc229b889299399136f45448a2b706df39d6d452ffc331c6b84c120b8fb
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built sentence-transformers pathtools
# Installing collected packages: smmap, pyyaml, tokenizers, huggingface-hub, gitdb, transformers, shortuuid, setproctitle, sentry-sdk, sentencepiece, pathtools, GitPython, docker-pycreds, xgboost, wandb, sentence-transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 0.90
#     Uninstalling xgboost-0.90:
#       Successfully uninstalled xgboost-0.90
# Successfully installed GitPython-3.1.27 docker-pycreds-0.4.0 gitdb-4.0.9 huggingface-hub-0.8.1 pathtools-0.1.2 pyyaml-6.0 sentence-transformers-2.2.2 sentencepiece-0.1.96 sentry-sdk-1.6.0 setproctitle-1.2.3 shortuuid-1.0.9 smmap-5.0.0 tokenizers-0.12.1 transformers-4.20.1 wandb-0.12.21 xgboost-1.6.1

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import re
import json

from sentence_transformers import SentenceTransformer 

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
import xgboost as xgb

import wandb
from wandb.xgboost import WandbCallback
from IPython.display import clear_output

# %%
metrics = [accuracy_score, f1_score, precision_score, recall_score]

def get_name(score_func):
    return score_func.__name__.split("_")[0]

# %% [markdown]
# # Load data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
base_dir = Path("/content/drive/MyDrive/ResearchFND")
assert base_dir.exists()

# %%
import ast

converters = {"retweets":ast.literal_eval, "tweets":ast.literal_eval}
df = pd.read_csv(base_dir/"politifact_agg.csv", converters=converters)
df.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0   Actress Emma Stone ‘For the first time in his...
# 1           1   Breaking President Trump makes English the of...
# 2           2   Friendly Fire … Charlottesville Car attacker ...
# 3           3   If You Are Using This Toothpaste… Throw It Aw...
# 4           4  "Face the Nation" transcripts, August 26, 2012...
#
#                                                 text tweets  \
# 0                                                NaN     []
# 1                                                NaN     []
# 2                                                NaN     []
# 3  MightyLiving Blog\n\nHelpful inspiration from ...     []
# 4  "Face the Nation" transcripts, August 26, 2012...     []
#
#                                             retweets label  \
# 0  [1020554564334964741, 1020817527046197248, 106...  fake
# 1                                                 []  fake
# 2  [3265439004, 3250621593, 3253922920, 326691851...  fake
# 3  [911971426571255810, 1036749614853103616, 1033...  fake
# 4                                                 []  real
#
#                                                  url tweet_ids  num_retweets  \
# 0                                                NaN        []          2911
# 1                                                NaN        []             0
# 2                                                NaN        []            24
# 3  mightynest.com/learn/research-by-concern/dange...        []          2569
# 4  https://web.archive.org/web/20120827001956/htt...        []             0
#
#    log_num_retweets  num_tweets  log_num_tweets
# 0          7.976595           0             0.0
# 1          0.000000           0             0.0
# 2          3.218876           0             0.0
# 3          7.851661           0             0.0
# 4          0.000000           0             0.0

# %%
df.title.isna().sum(), (df.title == "").sum()
# Out:
# (0, 0)

# %% [markdown]
# # Compute emebeddings

# %%
title_embedding_file = base_dir/"politifact_sbert_title_embeddings.npy"

if title_embedding_file.exists():
    title_embeddings = np.load(title_embedding_file)
else:
    model_id = "all-mpnet-base-v2"
    model = SentenceTransformer(model_id)
    titles = df.title.to_list()
    title_embeddings = model.encode(titles, show_progress_bar=True)
    np.save(title_embedding_file, title_embeddings)
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Batches:   0%|          | 0/28 [00:00<?, ?it/s]

# %%
df.text.isna().sum()
# Out:
# 153

# %%
text_embedding_file = base_dir/"politifact_sbert_fulltext_embeddings.npy"

if text_embedding_file.exists():
    text_embeddings = np.load(text_embedding_file)
else:
    model_id = "all-mpnet-base-v2"
    model = SentenceTransformer(model_id)
    df.text.fillna("", inplace=True)
    texts = df.title + "\n" + df.text
    text_embeddings = model.encode(texts, show_progress_bar=True)
    np.save(text_embedding_file, text_embeddings)
# Out:
# Batches:   0%|          | 0/28 [00:00<?, ?it/s]

# %% [markdown]
# # Extra features
#
# TODO: feel free to suggest more features here

# %% [markdown]
# ## Source

# %%
source = df.news_url.str.replace("^(https://)?web.archive.org/web/\d+/", "", regex=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-6aa77b073439> in <module>()
# ----> 1 source = df.news_url.str.replace("^(https://)?web.archive.org/web/\d+/", "", regex=True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'news_url'

# %%
source = source.str.replace("^(https?://)?(www.)?", "", regex=True)

# %%
source = source.str.replace("\.(com|info|org|gov|tv|us|news|me|co.uk|net|club|co|live|edu|xyz|site|life|ru|online|tk|website|pw|one|world|mil).*$", "", regex=True)

# %%
len(source), len(source.unique())

# %% [markdown]
# ## Number of retweets

# %%
df["num_retweets"] = df.retweets.map(lambda x: len(set(x)))
df["log_num_retweets"] = np.log1p(df.num_retweets.to_numpy())
df["num_tweets"] = df.tweets.map(lambda x: len(set([t["id"] for t in x])))
df["log_num_tweets"] = np.log1p(df.num_tweets.to_numpy())

# %%
df.describe()
# Out:
#        Unnamed: 0  num_retweets  log_num_retweets    num_tweets  \
# count  894.000000    894.000000        894.000000    894.000000
# mean   446.500000    646.884787          3.475319     70.429530
# std    258.219868   2461.779445          2.758056    778.521306
# min      0.000000      0.000000          0.000000      0.000000
# 25%    223.250000      1.000000          0.693147      0.000000
# 50%    446.500000     31.000000          3.465736      0.000000
# 75%    669.750000    305.750000          5.726032      0.000000
# max    893.000000  29060.000000         10.277152  21984.000000
#
#        log_num_tweets
# count      894.000000
# mean         0.742621
# std          1.815463
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          9.998116

# %% [markdown]
# # Training

# %%
WANDB_ENTITY = 'saloniteam'
WANDB_PROJECT = 'nofolds'

# %% [markdown]
# ### Title embeddings

# %%
X = title_embeddings
y = (df.label=="real").to_numpy().astype(int)

X.shape, y.shape
# Out:
# ((894, 768), (894,))

# %%
skf = StratifiedKFold(shuffle=True, random_state=124)

# %%
def train(train_idx, test_idx, params):

    # training
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dtest = xgb.DMatrix(X_test, label=y_test)
    watchlist = [(dtrain,'train'), (dtest,'eval')]
    clf = xgb.train(params, dtrain, num_boost_round=200, early_stopping_rounds=None, evals=watchlist, callbacks=[WandbCallback()])
    #evaluation
    probs = clf.predict(dtest)
    y_pred = (probs > 0.5).astype(int)
    eval_results = {get_name(f):f(y_pred=y_pred, y_true=y_test) for f in metrics}
    wandb.log(eval_results)
    wandb.log({"conf_mat" : wandb.plot.confusion_matrix(probs=None,
                            y_true=y_test, preds=y_pred,
                            class_names=["Fake", "Real"])})

# %%
params = {
    "objective":'binary:logistic',
    "seed":124
}

# %%
# !wandb login --relogin
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
GROUP = "politifact-sbert-mpnet-v2-title-xgb"

for fold_id, (train_idx, test_idx) in enumerate(skf.split(X, y)):
    clear_output()
    with wandb.init(entity=WANDB_ENTITY, project=WANDB_PROJECT, group=GROUP, name=f"{GROUP}_0") as run:
        train(train_idx, test_idx, params)
    break
# Out:
# wandb: Currently logged in as: saloni (saloniteam). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/content/wandb/run-20220710_153808-3jo8ifxh</code>
# Syncing run <strong><a href="https://wandb.ai/saloniteam/nofolds/runs/3jo8ifxh" target="_blank">politifact-sbert-mpnet-v2-title-xgb_0</a></strong> to <a href="https://wandb.ai/saloniteam/nofolds" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# [0]	train-logloss:0.50337	eval-logloss:0.63257
# [1]	train-logloss:0.37680	eval-logloss:0.54844
# [2]	train-logloss:0.29378	eval-logloss:0.50917
# [3]	train-logloss:0.23477	eval-logloss:0.46907
# [4]	train-logloss:0.18961	eval-logloss:0.45830
# [5]	train-logloss:0.15456	eval-logloss:0.45304
# [6]	train-logloss:0.12921	eval-logloss:0.43815
# [7]	train-logloss:0.10886	eval-logloss:0.41948
# [8]	train-logloss:0.09165	eval-logloss:0.41600
# [9]	train-logloss:0.07905	eval-logloss:0.40340
# [10]	train-logloss:0.06908	eval-logloss:0.40021
# [11]	train-logloss:0.06044	eval-logloss:0.39733
# [12]	train-logloss:0.05326	eval-logloss:0.38680
# [13]	train-logloss:0.04762	eval-logloss:0.37833
# [14]	train-logloss:0.04292	eval-logloss:0.37329
# [15]	train-logloss:0.03869	eval-logloss:0.36210
# [16]	train-logloss:0.03524	eval-logloss:0.35516
# [17]	train-logloss:0.03240	eval-logloss:0.35473
# [18]	train-logloss:0.02992	eval-logloss:0.35311
# [19]	train-logloss:0.02762	eval-logloss:0.35236
# [20]	train-logloss:0.02558	eval-logloss:0.35520
# [21]	train-logloss:0.02391	eval-logloss:0.35045
# [22]	train-logloss:0.02235	eval-logloss:0.34908
# [23]	train-logloss:0.02101	eval-logloss:0.34212
# [24]	train-logloss:0.01989	eval-logloss:0.34637
# [25]	train-logloss:0.01874	eval-logloss:0.34521
# [26]	train-logloss:0.01779	eval-logloss:0.34423
# [27]	train-logloss:0.01698	eval-logloss:0.34626
# [28]	train-logloss:0.01607	eval-logloss:0.34580
# [29]	train-logloss:0.01539	eval-logloss:0.34286
# [30]	train-logloss:0.01477	eval-logloss:0.34563
# [31]	train-logloss:0.01419	eval-logloss:0.34491
# [32]	train-logloss:0.01369	eval-logloss:0.34241
# [33]	train-logloss:0.01326	eval-logloss:0.34282
# [34]	train-logloss:0.01280	eval-logloss:0.34475
# [35]	train-logloss:0.01237	eval-logloss:0.34616
# [36]	train-logloss:0.01200	eval-logloss:0.34515
# [37]	train-logloss:0.01168	eval-logloss:0.34262
# [38]	train-logloss:0.01138	eval-logloss:0.34580
# [39]	train-logloss:0.01105	eval-logloss:0.34928
# [40]	train-logloss:0.01072	eval-logloss:0.35025
# [41]	train-logloss:0.01045	eval-logloss:0.34499
�▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.82682</td></tr><tr><td>epoch</td><td>199</td></tr><tr><td>f1</td><td>0.83598</td></tr><tr><td>precision</td><td>0.84946</td></tr><tr><td>recall</td><td>0.82292</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">politifact-sbert-mpnet-v2-title-xgb_0</strong>: <a href="https://wandb.ai/saloniteam/nofolds/runs/3jo8ifxh" target="_blank">https://wandb.ai/saloniteam/nofolds/runs/3jo8ifxh</a><br/>Synced 5 W&B file(s), 2 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220710_153808-3jo8ifxh/logs</code>

# %% [markdown]
# ### Text embeddings

# %%
X = text_embeddings
y = (df.label=="real").to_numpy().astype(int)

X.shape, y.shape
# Out:
# ((894, 768), (894,))

# %%
skf = StratifiedKFold(shuffle=True, random_state=124)

# %%
def train(train_idx, test_idx, params):

    # training
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dtest = xgb.DMatrix(X_test, label=y_test)
    watchlist = [(dtrain,'train'), (dtest,'eval')]
    clf = xgb.train(params, dtrain, num_boost_round=200, early_stopping_rounds=None, evals=watchlist, callbacks=[WandbCallback()])
    #evaluation
    probs = clf.predict(dtest)
    y_pred = (probs > 0.5).astype(int)
    eval_results = {get_name(f):f(y_pred=y_pred, y_true=y_test) for f in metrics}
    wandb.log(eval_results)
    wandb.log({"conf_mat" : wandb.plot.confusion_matrix(probs=None,
                            y_true=y_test, preds=y_pred,
                            class_names=["Fake", "Real"])})

# %%
params = {
    "objective":'binary:logistic',
    "seed":124
}

# %%
GROUP = "politifact-sbert-mpnet-v2-fulltext-xgb"
for fold_id, (train_idx, test_idx) in enumerate(skf.split(X, y)):
    clear_output()
    with wandb.init(entity=WANDB_ENTITY, project=WANDB_PROJECT, group=GROUP, name=f"{GROUP}_0") as run:
        train(train_idx, test_idx, params)
    break
# Out:
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/content/wandb/run-20220710_153842-1yoqykq1</code>
# Syncing run <strong><a href="https://wandb.ai/saloniteam/nofolds/runs/1yoqykq1" target="_blank">politifact-sbert-mpnet-v2-fulltext-xgb_0</a></strong> to <a href="https://wandb.ai/saloniteam/nofolds" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# [0]	train-logloss:0.50447	eval-logloss:0.61130
# [1]	train-logloss:0.38697	eval-logloss:0.55114
# [2]	train-logloss:0.29647	eval-logloss:0.49479
# [3]	train-logloss:0.23169	eval-logloss:0.45764
# [4]	train-logloss:0.18565	eval-logloss:0.43254
# [5]	train-logloss:0.15059	eval-logloss:0.42798
# [6]	train-logloss:0.12388	eval-logloss:0.41043
# [7]	train-logloss:0.10315	eval-logloss:0.39078
# [8]	train-logloss:0.08684	eval-logloss:0.37531
# [9]	train-logloss:0.07429	eval-logloss:0.36711
# [10]	train-logloss:0.06422	eval-logloss:0.35258
# [11]	train-logloss:0.05635	eval-logloss:0.35034
# [12]	train-logloss:0.04973	eval-logloss:0.33461
# [13]	train-logloss:0.04409	eval-logloss:0.33213
# [14]	train-logloss:0.03943	eval-logloss:0.32611
# [15]	train-logloss:0.03584	eval-logloss:0.32838
# [16]	train-logloss:0.03268	eval-logloss:0.32420
# [17]	train-logloss:0.02992	eval-logloss:0.31730
# [18]	train-logloss:0.02768	eval-logloss:0.31323
# [19]	train-logloss:0.02552	eval-logloss:0.30501
# [20]	train-logloss:0.02367	eval-logloss:0.30243
# [183]	train-logloss:0.00337	eval-logloss:0.25508
# [184]	train-logloss:0.00336	eval-logloss:0.25576
# [185]	train-logloss:0.00335	eval-logloss:0.25562
# [186]	train-logloss:0.00334	eval-logloss:0.25543
# [187]	train-logloss:0.00334	eval-logloss:0.25579
# [188]	train-logloss:0.00333	eval-logloss:0.25534
# [189]	train-logloss:0.00332	eval-logloss:0.25495
# [190]	train-logloss:0.00331	eval-logloss:0.25584
# [191]	train-logloss:0.00330	eval-logloss:0.25442
# [192]	train-logloss:0.00329	eval-logloss:0.25433
# [193]	train-logloss:0.00328	eval-logloss:0.25433
# [194]	train-logloss:0.00327	eval-logloss:0.25463
# [195]	train-logloss:0.00326	eval-logloss:0.25501
# [196]	train-logloss:0.00326	eval-logloss:0.25554
# [197]	train-logloss:0.00325	eval-logloss:0.25532
# [198]	train-logloss:0.00324	eval-logloss:0.25659
# [199]	train-logloss:0.00323	eval-logloss:0.25665
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.021 MB of 0.021 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.992819…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>eval-logloss</td><td>█▅▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>f1</td><td>▁</td></tr><tr><td>precision</td><td>▁</td></tr><tr><td>recall</td><td>▁</td></tr><tr><td>train-logloss</td><td>█▄▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.87709</td></tr><tr><td>epoch</td><td>199</td></tr><tr><td>f1</td><td>0.87778</td></tr><tr><td>precision</td><td>0.94048</td></tr><tr><td>recall</td><td>0.82292</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">politifact-sbert-mpnet-v2-fulltext-xgb_0</strong>: <a href="https://wandb.ai/saloniteam/nofolds/runs/1yoqykq1" target="_blank">https://wandb.ai/saloniteam/nofolds/runs/1yoqykq1</a><br/>Synced 5 W&B file(s), 2 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220710_153842-1yoqykq1/logs</code>

# %% [markdown]
# ### + num tweets and retweets

# %%
X = np.concatenate([text_embeddings, df.num_retweets.to_numpy()[..., None], df.num_tweets.to_numpy()[..., None]], axis=1)
y = (df.label=="real").to_numpy().astype(int)

X.shape, y.shape
# Out:
# ((894, 770), (894,))

# %%
skf = StratifiedKFold(shuffle=True, random_state=124)

# %%
def train(train_idx, test_idx, params):

    # training
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dtest = xgb.DMatrix(X_test, label=y_test)
    watchlist = [(dtrain,'train'), (dtest,'eval')]
    clf = xgb.train(params, dtrain, num_boost_round=200, early_stopping_rounds=None, evals=watchlist, callbacks=[WandbCallback()])
    #evaluation
    probs = clf.predict(dtest)
    y_pred = (probs > 0.5).astype(int)
    eval_results = {get_name(f):f(y_pred=y_pred, y_true=y_test) for f in metrics}
    wandb.log(eval_results)
    wandb.log({"conf_mat" : wandb.plot.confusion_matrix(probs=None,
                            y_true=y_test, preds=y_pred,
                            class_names=["Fake", "Real"])})

# %%
params = {
    "objective":'binary:logistic',
    "seed":124
}

# %%
GROUP = "politifact-sbert-mpnet-v2-fulltext-tw-xgb"
for fold_id, (train_idx, test_idx) in enumerate(skf.split(X, y)):
    clear_output()
    with wandb.init(entity=WANDB_ENTITY, project=WANDB_PROJECT, group=GROUP, name=f"{GROUP}-0") as run:
        train(train_idx, test_idx, params)
    break
# Out:
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>
# [158]	train-logloss:0.00356	eval-logloss:0.20347
# [159]	train-logloss:0.00354	eval-logloss:0.20308
# [160]	train-logloss:0.00353	eval-logloss:0.20302
# [161]	train-logloss:0.00352	eval-logloss:0.20263
# [162]	train-logloss:0.00351	eval-logloss:0.20152
# [163]	train-logloss:0.00350	eval-logloss:0.20210
# [164]	train-logloss:0.00349	eval-logloss:0.20250
# [165]	train-logloss:0.00348	eval-logloss:0.20259
# [166]	train-logloss:0.00347	eval-logloss:0.20208
# [167]	train-logloss:0.00346	eval-logloss:0.20234
# [168]	train-logloss:0.00345	eval-logloss:0.20224
# [169]	train-logloss:0.00344	eval-logloss:0.20265
# [170]	train-logloss:0.00343	eval-logloss:0.20298
# [171]	train-logloss:0.00342	eval-logloss:0.20279
# [172]	train-logloss:0.00341	eval-logloss:0.20298
# [173]	train-logloss:0.00340	eval-logloss:0.20278
# [174]	train-logloss:0.00339	eval-logloss:0.20297
# [175]	train-logloss:0.00338	eval-logloss:0.20357
# [176]	train-logloss:0.00337	eval-logloss:0.20357
# [177]	train-logloss:0.00336	eval-logloss:0.20361
# [178]	train-logloss:0.00335	eval-logloss:0.20353
# [179]	train-logloss:0.00334	eval-logloss:0.20369
# [180]	train-logloss:0.00333	eval-logloss:0.20442
# [181]	train-logloss:0.00332	eval-logloss:0.20494
# [182]	train-logloss:0.00331	eval-logloss:0.20447
# [183]	train-logloss:0.00330	eval-logloss:0.20460
# [184]	train-logloss:0.00329	eval-logloss:0.20405
# [185]	train-logloss:0.00328	eval-logloss:0.20386
# [186]	train-logloss:0.00327	eval-logloss:0.20320
# [187]	train-logloss:0.00326	eval-logloss:0.20344
# [188]	train-logloss:0.00325	eval-logloss:0.20335
# [189]	train-logloss:0.00325	eval-logloss:0.20341
# [190]	train-logloss:0.00324	eval-logloss:0.20321
# [191]	train-logloss:0.00323	eval-logloss:0.20391
# [192]	train-logloss:0.00322	eval-logloss:0.20365
# [193]	train-logloss:0.00321	eval-logloss:0.20284
# [194]	train-logloss:0.00320	eval-logloss:0.20281
# [195]	train-logloss:0.00319	eval-logloss:0.20280
# [196]	train-logloss:0.00319	eval-logloss:0.20281
# [197]	train-logloss:0.00318	eval-logloss:0.20271
# [198]	train-logloss:0.00317	eval-logloss:0.20312
# [199]	train-logloss:0.00316	eval-logloss:0.20307
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.018 MB of 0.018 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>eval-logloss</td><td>█▄▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>f1</td><td>▁</td></tr><tr><td>precision</td><td>▁</td></tr><tr><td>recall</td><td>▁</td></tr><tr><td>train-logloss</td><td>█▄▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.90503</td></tr><tr><td>epoch</td><td>199</td></tr><tr><td>f1</td><td>0.90811</td></tr><tr><td>precision</td><td>0.94382</td></tr><tr><td>recall</td><td>0.875</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">politifact-sbert-mpnet-v2-fulltext-tw-xgb-0</strong>: <a href="https://wandb.ai/saloniteam/nofolds/runs/37r29z0x" target="_blank">https://wandb.ai/saloniteam/nofolds/runs/37r29z0x</a><br/>Synced 5 W&B file(s), 2 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220710_153901-37r29z0x/logs</code>
