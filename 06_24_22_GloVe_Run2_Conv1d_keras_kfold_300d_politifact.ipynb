# %% [markdown]
# <a href="https://colab.research.google.com/github/verma-saloni/Thesis-Work/blob/main/06_24_22_GloVe_Run2_Conv1d_keras_kfold_300d_politifact.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install wandb

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
from sklearn.preprocessing import LabelBinarizer
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from wordcloud import WordCloud,STOPWORDS
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize,sent_tokenize
from bs4 import BeautifulSoup
import re,string,unicodedata
from keras.preprocessing import text, sequence
from nltk.tokenize.toktok import ToktokTokenizer
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.model_selection import train_test_split
from string import punctuation
from nltk import pos_tag
from nltk.corpus import wordnet
import keras
from keras.models import Sequential
from keras.layers import Dense,Embedding,LSTM,Dropout
import tensorflow as tf
import gensim.downloader as api

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from pathlib import Path

import wandb
from wandb.keras import WandbCallback
from IPython.display import clear_output


metrics = [accuracy_score, f1_score, precision_score, recall_score]

def get_name(score_func):
    return 'eval/' + score_func.__name__.split("_")[0]

# %%
from google.colab import drive
drive.mount('/content/drive')

base_dir = Path("/content/drive/MyDrive/ResearchFND")
assert base_dir.exists()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv(base_dir/"politifact_agg.csv", index_col=0)
df.head()
# Out:
#                                                title  \
# 0   Actress Emma Stone ‘For the first time in his...
# 1   Breaking President Trump makes English the of...
# 2   Friendly Fire … Charlottesville Car attacker ...
# 3   If You Are Using This Toothpaste… Throw It Aw...
# 4  "Face the Nation" transcripts, August 26, 2012...
#
#                                                 text tweets  \
# 0                                                NaN     []
# 1                                                NaN     []
# 2                                                NaN     []
# 3  MightyLiving Blog\n\nHelpful inspiration from ...     []
# 4  "Face the Nation" transcripts, August 26, 2012...     []
#
#                                             retweets label  \
# 0  ['1020554564334964741', '1020817527046197248',...  fake
# 1                                                 []  fake
# 2  ['3265439004', '3250621593', '3253922920', '32...  fake
# 3  ['911971426571255810', '1036749614853103616', ...  fake
# 4                                                 []  real
#
#                                                  url tweet_ids  num_retweets  \
# 0                                                NaN        []          2911
# 1                                                NaN        []             0
# 2                                                NaN        []            24
# 3  mightynest.com/learn/research-by-concern/dange...        []          2569
# 4  https://web.archive.org/web/20120827001956/htt...        []             0
#
#    log_num_retweets  num_tweets  log_num_tweets
# 0          7.976595           0             0.0
# 1          0.000000           0             0.0
# 2          3.218876           0             0.0
# 3          7.851661           0             0.0
# 4          0.000000           0             0.0

# %%
(df.title.str.len() == 0).any()
# Out:
# False

# %%
len(df), len(df.title.unique())
# Out:
# (894, 894)

# %%
news = df[['title', 'text', 'label']].copy()

print(news.isna().any())
news.count()
# Out:
# title    False
# text      True
# label    False
# dtype: bool
# title    894
# text     741
# label    894
# dtype: int64

# %%
import nltk
nltk.download('stopwords')

stop = set(stopwords.words('english'))
punctuation = list(string.punctuation)
stop.update(punctuation)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Removing the special characters and not useful characters from URLs, data cleaning step.

# %%
def strip_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

#Removing the square brackets
def remove_between_square_brackets(text):
    return re.sub('\[[^]]*\]', '', text)
# Removing URL's
def remove_between_square_brackets(text):
    return re.sub(r'http\S+', '', text)
#Removing the stopwords from text
def remove_stopwords(text):
    final_text = []
    for i in text.split():
        if i.strip().lower() not in stop:
            final_text.append(i.strip())
    return " ".join(final_text)
#Removing the noisy text
def denoise_text(text):
    text = strip_html(text)
    text = remove_between_square_brackets(text)
    text = remove_stopwords(text)
    return text
#Apply function on review column
news['title']= news['title'].apply(denoise_text)

# %%
#Tokenizing Text -> Repsesenting each word by a number
tokenizer = text.Tokenizer(oov_token="<unk>")
tokenizer.fit_on_texts(news.title)

# %%
d_wv = 50
glove = api.load(f'glove-wiki-gigaword-{d_wv}')

# %% [markdown]
# D_WV sets the length of the embedding vector.

# %%
emb_matrix = np.zeros((max(tokenizer.word_index.values())+1, d_wv), dtype=np.float32)
for i in range(1,max(tokenizer.word_index.values())+1):
    word = tokenizer.index_word[i]
    if word in glove.vocab:
        emb_matrix[i, :] = glove.word_vec(word)

# %%
len(tokenizer.word_index)
# Out:
# 3310

# %%
def get_model(emb_matrix):
    model = tf.keras.Sequential([
        #alternatively we can use glove.get_keras_embedding(),
        tf.keras.layers.Embedding(emb_matrix.shape[0], output_dim=emb_matrix.shape[1], weights=[emb_matrix],trainable=False, mask_zero=True),
        # tf.keras.layers.Average(),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Conv1D(256, 5, activation='relu'),
        tf.keras.layers.MaxPooling1D(pool_size=4),
        tf.keras.layers.LSTM(20, return_sequences=True),
        tf.keras.layers.LSTM(20),
        tf.keras.layers.Dropout(0.5),  
        tf.keras.layers.Dense(64),
        tf.keras.layers.Dropout(0.4),  
        tf.keras.layers.Dense(128),
        tf.keras.layers.Dropout(0.1),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
    return model

# %% [markdown]
# Creating a model with LSTM layers to see how architecture affects the performance.

# %%
model = get_model(emb_matrix)
model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_14 (Embedding)    (None, None, 50)          165550
#
#  dropout_43 (Dropout)        (None, None, 50)          0
#
#  conv1d_14 (Conv1D)          (None, None, 256)         64256
#
#  max_pooling1d (MaxPooling1D  (None, None, 256)        0
#  )
#
#  lstm_5 (LSTM)               (None, None, 20)          22160
#
#  lstm_6 (LSTM)               (None, 20)                3280
#
#  dropout_44 (Dropout)        (None, 20)                0
#
#  dense_29 (Dense)            (None, 64)                1344
#
#  dropout_45 (Dropout)        (None, 64)                0
#
#  dense_30 (Dense)            (None, 128)               8320
#
#  dropout_46 (Dropout)        (None, 128)               0
#
#  dense_31 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 265,039
# Trainable params: 99,489
# Non-trainable params: 165,550
# _________________________________________________________________

# %% [markdown]
# ## Titles

# %%
tokenized_titles = tokenizer.texts_to_sequences(news.title.tolist())
max_len = max(map(len, tokenized_titles))
X = sequence.pad_sequences(tokenized_titles, maxlen=max_len)
y = (df.label=="real").to_numpy().astype(int)

X.shape, y.shape
# Out:
# ((894, 25), (894,))

# %%
skf = StratifiedKFold(shuffle=True, random_state=124)

# %%
def train(fold_id, train_idx, test_idx, params):

    # setup
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]
    model = get_model(emb_matrix)
    # training
    ckpt_filepath = f'ckpt/fold_{fold_id}'
    save_model_cb = keras.callbacks.ModelCheckpoint(
        filepath=ckpt_filepath,
        save_weights_only=True,
        monitor='val_accuracy',
        mode='max',
        save_best_only=True)
    history = model.fit(
        X_train, y_train, validation_data = (X_test, y_test), 
        batch_size = params['bs'] , epochs=params['epochs'],
        callbacks=[WandbCallback(), save_model_cb]
    )
    #evaluation
    model.load_weights(ckpt_filepath)
    probs = model.predict(X_test).squeeze()
    y_pred = (probs > 0.5).astype(int)
    eval_results = {get_name(f):f(y_pred=y_pred, y_true=y_test) for f in metrics}
    wandb.log(eval_results)
    wandb.log({"conf_mat" : wandb.plot.confusion_matrix(probs=None,
                            y_true=y_test, preds=y_pred,
                            class_names=["Fake", "Real"])})
    return history

# %%
params = {
    "epochs":100,
    "bs":128,
    # 'lr':1e-3
}

# %%
GROUP = f"glove{d_wv}-title-convnet"

for fold_id, (train_idx, test_idx) in enumerate(skf.split(X, y)):
    clear_output()
    with wandb.init(entity="saloniteam", project="fnd", group=GROUP, name=f"{GROUP}-fold-{fold_id}") as run:
        train(fold_id, train_idx, test_idx, params)
# Out:
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220624_115220-637px914</code>
# Syncing run <strong><a href="https://wandb.ai/saloniteam/fnd/runs/637px914" target="_blank">glove50-title-convnet-fold-4</a></strong> to <a href="https://wandb.ai/saloniteam/fnd" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Epo
�▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.98883</td></tr><tr><td>best_epoch</td><td>3</td></tr><tr><td>best_val_loss</td><td>0.47504</td></tr><tr><td>epoch</td><td>99</td></tr><tr><td>eval/accuracy</td><td>0.86517</td></tr><tr><td>eval/f1</td><td>0.87879</td></tr><tr><td>eval/precision</td><td>0.85294</td></tr><tr><td>eval/recall</td><td>0.90625</td></tr><tr><td>loss</td><td>0.02737</td></tr><tr><td>val_accuracy</td><td>0.79775</td></tr><tr><td>val_loss</td><td>1.20278</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">glove50-title-convnet-fold-4</strong>: <a href="https://wandb.ai/saloniteam/fnd/runs/637px914" target="_blank">https://wandb.ai/saloniteam/fnd/runs/637px914</a><br/>Synced 5 W&B file(s), 2 media file(s), 1 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220624_115220-637px914/logs</code>

# %% [markdown]
# ## Fulltext

# %%
news['text'].fillna('', inplace=True)
news['text']= news['text'].apply(denoise_text)

news['fulltext'] = news['title'] + '\n' + news['text']

# %% [markdown]
# Using the full text of the news article to help with the prediction.

# %%
#Tokenizing Text -> Repsesenting each word by a number
tokenizer = text.Tokenizer(oov_token="<unk>")
tokenizer.fit_on_texts(news.fulltext)

# %%
emb_matrix = np.zeros((len(tokenizer.word_index)+1, d_wv), dtype=np.float32)
for i in range(1,max(tokenizer.word_index.values())+1):
    word = tokenizer.index_word[i]
    if word in glove.vocab:
        emb_matrix[i, :] = glove.word_vec(word)
print(emb_matrix.shape)
# Out:
# (33444, 50)

# %% [markdown]
# Creating an embedding matrix for the text too, so that it can be used as input.

# %%
tokenized_texts = tokenizer.texts_to_sequences(news.fulltext.tolist())
max_len = 128
X = sequence.pad_sequences(tokenized_texts, maxlen=max_len)
y = (df.label=="real").to_numpy().astype(int)

X.shape, y.shape
# Out:
# ((894, 128), (894,))

# %%
params = {
    "epochs":100,
    "bs":128,
    # 'lr':1e-3
}

# %%
GROUP = f"glove{d_wv}-fulltext{max_len}-convnet"

for fold_id, (train_idx, test_idx) in enumerate(skf.split(X, y)):
    clear_output()
    with wandb.init(entity="saloniteam", project="fnd", group=GROUP, name=f"{GROUP}-fold-{fold_id}") as run:
        train(fold_id, train_idx, test_idx, params)
# Out:
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220624_115442-ejyqqtke</code>
# Syncing run <strong><a href="https://wandb.ai/saloniteam/fnd/runs/ejyqqtke" target="_blank">glove50-fulltext128-convnet-fold-4</a></strong> to <a href="https://wandb.ai/saloniteam/fnd" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Epoch 1/100
# 6/6 [==============================] - 4s 189ms/step - loss: 0.6851 - accuracy: 0.5670 - val_loss: 0.6446 - val_accuracy: 0.6798 - _timestamp: 1656071688.0000 - _runtime: 6.0000
# Epoch 2/100
# 6/6 [==============================] - 0s 37ms/step - loss: 0.6135 - accuracy: 0.7151 - val_loss: 0.5491 - val_accuracy: 0.7416 - _timestamp: 1656071689.0000 - _runtime: 7.0000
# Epoch 3/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.5271 - accuracy: 0.7556 - val_loss: 0.5583 - val_accuracy: 0.6966 - _timestamp: 1656071689.0000 - _runtime: 7.0000
# Epoch 4/100
# 6/6 [==============================] - 0s 37ms/step - loss: 0.5367 - accuracy: 0.7514 - val_loss: 0.4717 - val_accuracy: 0.7921 - _timestamp: 1656071689.0000 - _runtime: 7.0000
# Epoch 5/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.4511 - accuracy: 0.8142 - val_loss: 0.4997 - val_accuracy: 0.7753 - _timestamp: 1656071689.0000 - _runtime: 7.0000
# Epoch
- _timestamp: 1656071696.0000 - _runtime: 14.0000
# Epoch 77/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0173 - accuracy: 0.9930 - val_loss: 1.1738 - val_accuracy: 0.8371 - _timestamp: 1656071696.0000 - _runtime: 14.0000
# Epoch 78/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0238 - accuracy: 0.9902 - val_loss: 1.2031 - val_accuracy: 0.8371 - _timestamp: 1656071696.0000 - _runtime: 14.0000
# Epoch 79/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0174 - accuracy: 0.9944 - val_loss: 1.2642 - val_accuracy: 0.8427 - _timestamp: 1656071696.0000 - _runtime: 14.0000
# Epoch 80/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0254 - accuracy: 0.9930 - val_loss: 1.2724 - val_accuracy: 0.8146 - _timestamp: 1656071697.0000 - _runtime: 15.0000
# Epoch 81/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0204 - accuracy: 0.9916 - val_loss: 1.2427 - val_accuracy: 0.8427 - _timestamp: 1656071697.0000 - _runtime: 15.0000
# Epoch 82/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0083 - accuracy: 0.9986 - val_loss: 1.3226 - val_accuracy: 0.8371 - _timestamp: 1656071697.0000 - _runtime: 15.0000
# Epoch 83/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0134 - accuracy: 0.9930 - val_loss: 1.3368 - val_accuracy: 0.8371 - _timestamp: 1656071697.0000 - _runtime: 15.0000
# Epoch 84/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0069 - accuracy: 0.9986 - val_loss: 1.4287 - val_accuracy: 0.8483 - _timestamp: 1656071697.0000 - _runtime: 15.0000
# Epoch 85/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0146 - accuracy: 0.9930 - val_loss: 1.4567 - val_accuracy: 0.8483 - _timestamp: 1656071697.0000 - _runtime: 15.0000
# Epoch 86/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0154 - accuracy: 0.9930 - val_loss: 1.4795 - val_accuracy: 0.8483 - _timestamp: 1656071697.0000 - _runtime: 15.0000
# Epoch 87/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0201 - accuracy: 0.9944 - val_loss: 1.3890 - val_accuracy: 0.8539 - _timestamp: 1656071697.0000 - _runtime: 15.0000
# Epoch 88/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 1.3524 - val_accuracy: 0.8596 - _timestamp: 1656071697.0000 - _runtime: 15.0000
# Epoch 89/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0137 - accuracy: 0.9944 - val_loss: 1.2790 - val_accuracy: 0.8483 - _timestamp: 1656071697.0000 - _runtime: 15.0000
# Epoch 90/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0166 - accuracy: 0.9930 - val_loss: 1.3993 - val_accuracy: 0.8652 - _timestamp: 1656071697.0000 - _runtime: 15.0000
# Epoch 91/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0123 - accuracy: 0.9930 - val_loss: 1.4392 - val_accuracy: 0.8427 - _timestamp: 1656071698.0000 - _runtime: 16.0000
# Epoch 92/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0384 - accuracy: 0.9916 - val_loss: 1.3689 - val_accuracy: 0.8539 - _timestamp: 1656071698.0000 - _runtime: 16.0000
# Epoch 93/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0087 - accuracy: 0.9944 - val_loss: 1.4476 - val_accuracy: 0.8202 - _timestamp: 1656071698.0000 - _runtime: 16.0000
# Epoch 94/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0118 - accuracy: 0.9944 - val_loss: 1.2880 - val_accuracy: 0.8483 - _timestamp: 1656071698.0000 - _runtime: 16.0000
# Epoch 95/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0152 - accuracy: 0.9958 - val_loss: 1.2243 - val_accuracy: 0.8427 - _timestamp: 1656071698.0000 - _runtime: 16.0000
# Epoch 96/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0073 - accuracy: 0.9958 - val_loss: 1.2732 - val_accuracy: 0.8539 - _timestamp: 1656071698.0000 - _runtime: 16.0000
# Epoch 97/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0073 - accuracy: 0.9986 - val_loss: 1.3435 - val_accuracy: 0.8539 - _timestamp: 1656071698.0000 - _runtime: 16.0000
# Epoch 98/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0081 - accuracy: 0.9972 - val_loss: 1.4198 - val_accuracy: 0.8427 - _timestamp: 1656071698.0000 - _runtime: 16.0000
# Epoch 99/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0087 - accuracy: 0.9958 - val_loss: 1.4103 - val_accuracy: 0.8483 - _timestamp: 1656071698.0000 - _runtime: 16.0000
# Epoch 100/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0044 - accuracy: 0.9986 - val_loss: 1.3885 - val_accuracy: 0.8315 - _timestamp: 1656071698.0000 - _runtime: 16.0000
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='7.590 MB of 7.590 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.999980…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▄▅▆▆▇▇▇▇▇▇██████████████████▇██████████</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>eval/accuracy</td><td>▁</td></tr><tr><td>eval/f1</td><td>▁</td></tr><tr><td>eval/precision</td><td>▁</td></tr><tr><td>eval/recall</td><td>▁</td></tr><tr><td>loss</td><td>█▆▆▅▄▃▃▃▃▃▂▂▁▁▁▁▁▂▁▁▁▁▁▂▂▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▂▅▅▅▇▇▆▄▅█▇█▇██▇▇████▆▇▇▇▇▇▆▄▇▇▇▇█▇█▇█▇</td></tr><tr><td>val_loss</td><td>▂▁▁▁▁▁▁▂▃▂▂▂▃▅▃▄▄▃▃▄▅▆█▃▄▄▅▆▄▆▄▅▅▅▅▅▅▅▅▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.9986</td></tr><tr><td>best_epoch</td><td>6</td></tr><tr><td>best_val_loss</td><td>0.46972</td></tr><tr><td>epoch</td><td>99</td></tr><tr><td>eval/accuracy</td><td>0.86517</td></tr><tr><td>eval/f1</td><td>0.875</td></tr><tr><td>eval/precision</td><td>0.875</td></tr><tr><td>eval/recall</td><td>0.875</td></tr><tr><td>loss</td><td>0.00445</td></tr><tr><td>val_accuracy</td><td>0.83146</td></tr><tr><td>val_loss</td><td>1.38854</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">glove50-fulltext128-convnet-fold-4</strong>: <a href="https://wandb.ai/saloniteam/fnd/runs/ejyqqtke" target="_blank">https://wandb.ai/saloniteam/fnd/runs/ejyqqtke</a><br/>Synced 5 W&B file(s), 2 media file(s), 1 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220624_115442-ejyqqtke/logs</code>
